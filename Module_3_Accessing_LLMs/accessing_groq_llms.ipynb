# %% [markdown]
# ## Accessing GROQ LLMs

# %%
import os
import base64
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from IPython.display import Image

# %%
GROQ_API_KEY = os.environ.get("GROQ_API_KEY")

if GROQ_API_KEY:
    os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %% [markdown]
# ### Text to Text

# %%
llm = ChatGroq(model="qwen/qwen3-32b")

# %%
messages = [
    (
        "system", 
        "You are a helpful assistant that translates English to French. Translate the user sentence"
    ),
    (
        "human",
        "I love programming"
    )
]

# %%
ai_response = llm.invoke(messages)
ai_response.content
# Out:
# '<think>\nOkay, the user wants to translate "I love programming" into French. Let me start by breaking down the sentence.\n\nThe subject is "I", which in French is "Je". Then "love" – the verb here. In French, "love" as in a strong affection is "aime" when in the first person singular. So "I love" would be "J\'aime".\n\nNext is "programming". That\'s the object of the sentence. The French word for programming is "la programmation". So putting it all together: "J\'aime la programmation."\n\nWait, but should I check if there\'s any other way to phrase it? Maybe "J’adore la programmation" if they want to emphasize a stronger love. But the original sentence uses "love", which is "aime" in French. "Adore" is a bit stronger, like "love" as in "adorer". But the user said "love", so sticking with "aime" is safer.\n\nAlso, in French, the definite article "la" is used before "programmation" because it\'s a feminine noun. So "la programmation" is correct. \n\nNo contractions needed here except for "J\'aime" where the "e" in "je" combines with the "a" in "aime". That\'s correct. \n\nI think that\'s all. The translation should be accurate. Let me just confirm once more. Yes, "J\'aime la programmation" is the correct translation for "I love programming".\n</think>\n\nJ\'aime la programmation.'

# %% [markdown]
# ### Image to Text

# %%
llm = ChatGroq(
    model="meta-llama/llama-4-scout-17b-16e-instruct"
)

# %%
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "What is this a picture of?"
        },
        {
            "type": "image_url",
            "image_url": {
                "url" : "https://www.kindpng.com/picc/m/554-5542873_funny-dog-smile-freetoedit-funny-dog-png-transparent.png"
            },
        },
    ]
)

# %%
response = llm.invoke([message])
print(response.content)
# Out:
# The image depicts a dog, likely a Golden Retriever or a similar breed, wearing an orange jacket. The dog is shown from the shoulders up, facing to the right of the image. It has a tan coat with white fur around its chin and mouth, and its eyes are slightly squinted. The dog's nose is black, and it appears to be smiling or panting.
#
# The dog is wearing an orange jacket with a collar and a small orange tab on the right side of its neck. The background of the image is solid white, suggesting that it may have been edited or taken in a studio setting. Overall, the image presents a clear and detailed view of the dog's head and upper body, highlighting its features and expression.
