# %% [markdown]
# ## Accessing LLMs via Ollama

# %%
import base64
from pathlib import Path
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

# %% [markdown]
# ### Text to Text

# %%
llm = ChatOllama(
    model="llama3",
    temperature=0
)

# %%
messages = [
    SystemMessage(content="You are a helpful AI assistant."),
    HumanMessage(content="Explain RAG in simple words.")
]

# %%
response = llm.invoke(messages)

# %%
response.content
# Out:
# "RAG stands for Red, Amber, Green. It's a simple way to categorize things into three levels of priority or status.\n\nHere's what each color means:\n\n* **Red** (R): High priority or urgent. Something needs attention right away.\n* **Amber** (A): Medium priority or caution. Something requires some attention, but it's not critical.\n* **Green** (G): Low priority or good to go. Everything is fine and no action is needed.\n\nPeople often use RAG to label tasks, projects, or even people in a team. It helps them quickly see what needs attention and prioritize their work accordingly."

# %% [markdown]
# ### Image to Text

# %%
def encode_image(image_path: str) -> str:
    image_bytes = Path(image_path).read_bytes()
    return base64.b64encode(image_bytes).decode("utf-8")

# %%
image_b64 = encode_image("images/funny_dog_2.png")

# %%
llm = ChatOllama(
    model="bakllava",
    temperature=0
)

# %%
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Describe this image in detail."
        },
        {
            "type": "image_url",
            "image_url": f"data:image/jpeg;base64,{image_b64}"
        }
    ]
)

# %%
response = llm.invoke([message])
print(response.content)
# Out:
#  The image features a large brown dog with a big smile on its face, giving the impression of a happy and playful pet. The dog's tongue is sticking out, adding to the joyful expression. In front of the dog, there is a red object that seems to be a part of the scene.
#
# The image has a white background, which highlights the dog and brings focus to the subject. The dog occupies most of the frame, from the left side almost all the way to the right side of the image.
