# %% [markdown]
# ## Accessing LLMs via Open Router

# %%
import os
import base64
from langchain_openrouter import ChatOpenRouter
from langchain_core.messages import HumanMessage, SystemMessage
from IPython.display import Image

# %%
OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY")

if OPENROUTER_API_KEY:
    os.environ["OPENROUTER_API_KEY"] = OPENROUTER_API_KEY

# %% [markdown]
# ### Text to Text

# %%
llm = ChatOpenRouter(
    model_name="anthropic/claude-haiku-4.5",
    max_tokens=1024
)

# %%
messages = [
    SystemMessage(content="You are a helpful and concise AI assistant."),
    HumanMessage(content="Can you talk about the climate change?.")
]

# %%
response = llm.invoke(messages)
print(response.content)
# Out:
# # Climate Change Overview
#
# **What it is:**
# Climate change refers to long-term shifts in global temperatures and weather patterns, primarily caused by human activities—especially burning fossil fuels (coal, oil, gas), which releases greenhouse gases like CO₂.
#
# **Key impacts:**
# - Rising global temperatures
# - Melting ice caps and rising sea levels
# - Extreme weather events (hurricanes, droughts, floods)
# - Threats to ecosystems and biodiversity
# - Food and water security challenges
#
# **Current status:**
# - Global temperatures have risen ~1.1°C since pre-industrial times
# - Most climate scientists (97%+) agree human activity is the main cause
# - We're already experiencing measurable effects
#
# **Solutions being pursued:**
# - Transitioning to renewable energy (solar, wind)
# - Improving energy efficiency
# - Protecting forests
# - Developing carbon capture technology
# - Policy changes and international agreements (Paris Agreement)
#
# **What individuals can do:**
# - Reduce energy consumption
# - Support renewable energy
# - Make sustainable lifestyle choices
# - Vote for climate-conscious policies
#
# Is there a specific aspect of climate change you'd like to explore further?
